# %% [markdown]
# # Testing the model

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117 --upgrade
     

# !pip install langchain langchain_core einops accelerate transformers bitsandbytes scipy
     

# !pip install xformers sentencepiece 
     

# !pip install llama-index
# %pip install llama-index-embeddings-huggingface
# %pip install llama-index-llms-huggingface


# !pip install python-dotenv
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu117
# Requirement already satisfied: torch in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (2.1.2.post102)
# Requirement already satisfied: torchvision in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (0.16.1)
# ERROR: Could not find a version that satisfies the requirement torchaudio (from versions: none)
# ERROR: No matching distribution found for torchaudio
# Requirement already satisfied: langchain in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (0.1.13)
# Requirement already satisfied: langchain_core in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (0.1.51)
# Requirement already satisfied: einops in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (0.7.0)
# Requirement already satisfied: accelerate in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (0.27.0)
# Requirement already satisfied: transformers in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (4.38.2)
# Requirement already satisfied: bitsandbytes in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (0.42.0)
# Requirement already satisfied: scipy in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (1.12.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (3.9.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (0.5.14)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.29 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (0.0.36)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (0.1.54)
# Requirement already satisfied: numpy<2,>=1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain_core) (23.2)
# Requirement already satisfied: psutil in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: torch>=1.10.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from accelerate) (2.1.2.post102)
# Requirement already satisfied: huggingface-hub in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from huggingface-hub->accelerate) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from huggingface-hub->accelerate) (4.10.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from requests<3,>=2->langchain) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sympy in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Collecting xformers
#   Using cached xformers-0.0.26.post1.tar.gz (4.1 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sentencepiece in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (0.1.99)
# Requirement already satisfied: torch>=2.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from xformers) (2.1.2.post102)
# Requirement already satisfied: numpy in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from xformers) (1.26.4)
# Requirement already satisfied: filelock in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from torch>=2.1->xformers) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from torch>=2.1->xformers) (4.10.0)
# Requirement already satisfied: sympy in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from torch>=2.1->xformers) (1.12)
# Requirement already satisfied: networkx in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from torch>=2.1->xformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from torch>=2.1->xformers) (3.1.3)
# Requirement already satisfied: fsspec in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from torch>=2.1->xformers) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from jinja2->torch>=2.1->xformers) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from sympy->torch>=2.1->xformers) (1.3.0)
# Building wheels for collected packages: xformers
#   Building wheel for xformers (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [245 lines of output]
#       running bdist_wheel
#       /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/torch/utils/cpp_extension.py:502: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#         warnings.warn(msg.format('we could not find ninja.'))
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-312
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers
#       copying xformers/_deprecation_warning.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers
#       copying xformers/attn_bias_utils.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers
#       copying xformers/checkpoint.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers
#       copying xformers/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers
#       copying xformers/test.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers
#       copying xformers/utils.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers
#       copying xformers/_cpp_lib.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers
#       copying xformers/info.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/fused_linear_layer.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/vararg_kernel.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/k_activations.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/k_layer_norm.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/k_fused_matmul_fw.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/dropout.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/k_dropout.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/softmax.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/layer_norm.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/k_fused_matmul_bw.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       copying xformers/triton/k_softmax.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/triton
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/components
#       copying xformers/components/simplicial_embedding.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components
#       copying xformers/components/residual.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components
#       copying xformers/components/reversible.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components
#       copying xformers/components/activations.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components
#       copying xformers/components/multi_head_dispatch.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components
#       copying xformers/components/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components
#       copying xformers/components/input_projection.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components
#       copying xformers/components/patch_embedding.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_mem_eff_attention.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_indexing.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_mlp.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_blocksparse_transformers.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_transformer.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_revnet.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_swiglu.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_triton_layernorm.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_causal_blocksparse.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_triton_fused_linear.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_tiled_matmul.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_triton_blocksparse.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_triton_softmax.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/utils.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_triton_dropout.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_nystrom_utils.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_attn_decoding.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_multi_head_dispatch.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_sequence_parallel_fused.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_sddmm.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_sp24.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       copying xformers/benchmarks/benchmark_core.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/rmsnorm.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/modpar_layers.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/swiglu_op.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/unbind.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/rope_padded.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/seqpar.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/ipc.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/sequence_parallel_fused_ops.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/sp24.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/common.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/differentiable_collectives.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/tiled_matmul.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       copying xformers/ops/indexing.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/profiler
#       copying xformers/profiler/device_limits.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/profiler
#       copying xformers/profiler/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/profiler
#       copying xformers/profiler/profiler_dcgm_impl.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/profiler
#       copying xformers/profiler/profiler_dcgm.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/profiler
#       copying xformers/profiler/api.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/profiler
#       copying xformers/profiler/slow_ops_profiler.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/profiler
#       copying xformers/profiler/profiler.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/profiler
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/sparse
#       copying xformers/sparse/_csr_ops.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/sparse
#       copying xformers/sparse/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/sparse
#       copying xformers/sparse/utils.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/sparse
#       copying xformers/sparse/blocksparse_tensor.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/sparse
#       copying xformers/sparse/csr_tensor.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/sparse
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/helpers
#       copying xformers/helpers/test_utils.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/helpers
#       copying xformers/helpers/hierarchical_configs.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/helpers
#       copying xformers/helpers/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/helpers
#       copying xformers/helpers/timm_sparse_attention.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/helpers
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn
#       copying xformers/_flash_attn/fused_softmax.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn
#       copying xformers/_flash_attn/flash_blocksparse_attn_interface.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn
#       copying xformers/_flash_attn/flash_blocksparse_attention.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn
#       copying xformers/_flash_attn/bert_padding.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn
#       copying xformers/_flash_attn/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn
#       copying xformers/_flash_attn/flash_attn_triton_og.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn
#       copying xformers/_flash_attn/flash_attn_triton.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn
#       copying xformers/_flash_attn/flash_attn_interface.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/factory
#       copying xformers/factory/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/factory
#       copying xformers/factory/hydra_helper.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/factory
#       copying xformers/factory/block_factory.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/factory
#       copying xformers/factory/model_factory.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/factory
#       copying xformers/factory/block_configs.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/factory
#       copying xformers/factory/weight_init.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/factory
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/global_tokens.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/ortho.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/blocksparse.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/local.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/compositional.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/pooling.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/_sputnik_sparse.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/core.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/lambda_layer.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/random.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/fourier_mix.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/scaled_dot_product.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/utils.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/attention_mask.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/linformer.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/attention_patterns.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/visual.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/sparsity_config.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/nystrom.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/favor.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       copying xformers/components/attention/base.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/feedforward
#       copying xformers/components/feedforward/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/feedforward
#       copying xformers/components/feedforward/mixture_of_experts.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/feedforward
#       copying xformers/components/feedforward/mlp.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/feedforward
#       copying xformers/components/feedforward/conv_mlp.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/feedforward
#       copying xformers/components/feedforward/fused_mlp.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/feedforward
#       copying xformers/components/feedforward/base.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/feedforward
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/positional_embedding
#       copying xformers/components/positional_embedding/vocab.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/positional_embedding
#       copying xformers/components/positional_embedding/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/positional_embedding
#       copying xformers/components/positional_embedding/param.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/positional_embedding
#       copying xformers/components/positional_embedding/sine.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/positional_embedding
#       copying xformers/components/positional_embedding/rotary.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/positional_embedding
#       copying xformers/components/positional_embedding/base.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/positional_embedding
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention/feature_maps
#       copying xformers/components/attention/feature_maps/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention/feature_maps
#       copying xformers/components/attention/feature_maps/softmax.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention/feature_maps
#       copying xformers/components/attention/feature_maps/base.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/components/attention/feature_maps
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks/LRA
#       copying xformers/benchmarks/LRA/batch_submit.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks/LRA
#       copying xformers/benchmarks/LRA/batch_fetch_results.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks/LRA
#       copying xformers/benchmarks/LRA/run_with_submitit.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks/LRA
#       copying xformers/benchmarks/LRA/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks/LRA
#       copying xformers/benchmarks/LRA/run_tasks.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks/LRA
#       copying xformers/benchmarks/LRA/run_grid_search.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks/LRA
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks/LRA/code
#       copying xformers/benchmarks/LRA/code/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks/LRA/code
#       copying xformers/benchmarks/LRA/code/model_wrapper.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks/LRA/code
#       copying xformers/benchmarks/LRA/code/dataset.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/benchmarks/LRA/code
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/_triton
#       copying xformers/ops/_triton/k_scaled_index_add.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/_triton
#       copying xformers/ops/_triton/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/_triton
#       copying xformers/ops/_triton/rope_padded_kernels.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/_triton
#       copying xformers/ops/_triton/sequence_parallel_fused_kernels.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/_triton
#       copying xformers/ops/_triton/tiled_matmul_kernels.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/_triton
#       copying xformers/ops/_triton/k_index_select_cat.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/_triton
#       copying xformers/ops/_triton/rmsnorm_kernels.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/_triton
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/decoder.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/dispatch.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/attn_bias.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/ck.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/common.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/ck_decoder.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/flash.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/small_k.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/cutlass.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/ck_splitk.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       copying xformers/ops/fmha/triton_splitk.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/ops/fmha
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/losses
#       copying xformers/_flash_attn/losses/cross_entropy.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/losses
#       copying xformers/_flash_attn/losses/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/losses
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/layers
#       copying xformers/_flash_attn/layers/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/layers
#       copying xformers/_flash_attn/layers/patch_embed.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/layers
#       copying xformers/_flash_attn/layers/rotary.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/layers
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/utils
#       copying xformers/_flash_attn/utils/pretrained.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/utils
#       copying xformers/_flash_attn/utils/generation.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/utils
#       copying xformers/_flash_attn/utils/benchmark.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/utils
#       copying xformers/_flash_attn/utils/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/utils
#       copying xformers/_flash_attn/utils/distributed.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/utils
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/bigcode.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/gptj.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/opt.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/llama.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/vit.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/btlm.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/baichuan.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/bert.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/falcon.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/gpt_neox.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       copying xformers/_flash_attn/models/gpt.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/models
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops
#       copying xformers/_flash_attn/ops/activations.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops
#       copying xformers/_flash_attn/ops/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops
#       copying xformers/_flash_attn/ops/fused_dense.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops
#       copying xformers/_flash_attn/ops/rms_norm.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops
#       copying xformers/_flash_attn/ops/layer_norm.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/modules
#       copying xformers/_flash_attn/modules/embedding.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/modules
#       copying xformers/_flash_attn/modules/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/modules
#       copying xformers/_flash_attn/modules/mlp.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/modules
#       copying xformers/_flash_attn/modules/block.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/modules
#       copying xformers/_flash_attn/modules/mha.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/modules
#       creating build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops/triton
#       copying xformers/_flash_attn/ops/triton/cross_entropy.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops/triton
#       copying xformers/_flash_attn/ops/triton/linear.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops/triton
#       copying xformers/_flash_attn/ops/triton/k_activations.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops/triton
#       copying xformers/_flash_attn/ops/triton/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops/triton
#       copying xformers/_flash_attn/ops/triton/mlp.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops/triton
#       copying xformers/_flash_attn/ops/triton/rotary.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops/triton
#       copying xformers/_flash_attn/ops/triton/layer_norm.py -> build/lib.macosx-10.9-x86_64-cpython-312/xformers/_flash_attn/ops/triton
#       running build_ext
#       building 'xformers._C' extension
#       creating build/temp.macosx-10.9-x86_64-cpython-312
#       creating build/temp.macosx-10.9-x86_64-cpython-312/xformers
#       creating build/temp.macosx-10.9-x86_64-cpython-312/xformers/csrc
#       creating build/temp.macosx-10.9-x86_64-cpython-312/xformers/csrc/attention
#       creating build/temp.macosx-10.9-x86_64-cpython-312/xformers/csrc/attention/autograd
#       creating build/temp.macosx-10.9-x86_64-cpython-312/xformers/csrc/attention/cpu
#       creating build/temp.macosx-10.9-x86_64-cpython-312/xformers/csrc/sequence_parallel_fused
#       creating build/temp.macosx-10.9-x86_64-cpython-312/xformers/csrc/sparse24
#       creating build/temp.macosx-10.9-x86_64-cpython-312/xformers/csrc/swiglu
#       clang -fno-strict-overflow -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /Users/steven/opt/anaconda3/envs/llama_banker/include -fPIC -O2 -isystem /Users/steven/opt/anaconda3/envs/llama_banker/include -I/private/var/folders/j_/l3vzl03913z2sw704nqb4lfc0000gn/T/pip-install-2bppxepf/xformers_ed7078f8b96946819608a5c9b379461f/xformers/csrc -I/Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/torch/include -I/Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/torch/include/torch/csrc/api/include -I/Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/torch/include/TH -I/Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/torch/include/THC -I/Users/steven/opt/anaconda3/envs/llama_banker/include/python3.12 -c xformers/csrc/attention/attention.cpp -o build/temp.macosx-10.9-x86_64-cpython-312/xformers/csrc/attention/attention.o -O3 -std=c++17 -fopenmp -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_clang\" -DPYBIND11_STDLIB=\"_libcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1002\" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0
#       clang: error: unsupported option '-fopenmp'
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for xformers
#   Running setup.py clean for xformers
# Failed to build xformers
# ERROR: Could not build wheels for xformers, which is required to install pyproject.toml-based projects
# Requirement already satisfied: llama-index in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (0.7.21)
# Requirement already satisfied: tiktoken in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (0.5.2)
# Requirement already satisfied: dataclasses-json in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (0.5.14)
# Requirement already satisfied: langchain>=0.0.218 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (0.1.13)
# Requirement already satisfied: sqlalchemy>=2.0.15 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (2.0.30)
# Requirement already satisfied: numpy in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (1.26.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (8.2.3)
# Requirement already satisfied: openai>=0.26.4 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (1.25.2)
# Requirement already satisfied: pandas in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (2.2.1)
# Requirement already satisfied: urllib3<2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (1.26.18)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (2024.2.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (4.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (4.12.3)
# Requirement already satisfied: nest-asyncio in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index) (1.6.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain>=0.0.218->llama-index) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain>=0.0.218->llama-index) (3.9.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain>=0.0.218->llama-index) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.29 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain>=0.0.218->llama-index) (0.0.36)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.33 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain>=0.0.218->llama-index) (0.1.51)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain>=0.0.218->llama-index) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain>=0.0.218->llama-index) (0.1.54)
# Requirement already satisfied: pydantic<3,>=1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain>=0.0.218->llama-index) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain>=0.0.218->llama-index) (2.31.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from dataclasses-json->llama-index) (3.21.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from openai>=0.26.4->llama-index) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from openai>=0.26.4->llama-index) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from openai>=0.26.4->llama-index) (0.27.0)
# Requirement already satisfied: sniffio in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from openai>=0.26.4->llama-index) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from openai>=0.26.4->llama-index) (4.66.2)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from sqlalchemy>=2.0.15->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from beautifulsoup4->llama-index) (2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pandas->llama-index) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pandas->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pandas->llama-index) (2024.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from tiktoken->llama-index) (2023.12.25)
# Requirement already satisfied: attrs>=17.3.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.218->llama-index) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.218->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.218->llama-index) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.218->llama-index) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.218->llama-index) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=0.26.4->llama-index) (3.6)
# Requirement already satisfied: certifi in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=0.26.4->llama-index) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=0.26.4->llama-index) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=0.26.4->llama-index) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain>=0.0.218->llama-index) (2.4)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain>=0.0.218->llama-index) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain>=0.0.218->llama-index) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pydantic<3,>=1->langchain>=0.0.218->llama-index) (0.6.0)
# ...
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.21.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from scikit-learn->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (3.3.0)
# Requirement already satisfied: six>=1.5 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from sympy->torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-llms-huggingface in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (0.1.5)
# Requirement already satisfied: huggingface-hub<0.21.0,>=0.20.3 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-llms-huggingface) (0.20.3)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-llms-huggingface) (0.10.34)
# Requirement already satisfied: text-generation<0.8.0,>=0.7.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-llms-huggingface) (0.7.0)
# Requirement already satisfied: torch<3.0.0,>=2.1.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-llms-huggingface) (2.1.2.post102)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (4.38.2)
# Requirement already satisfied: filelock in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (2024.2.0)
# Requirement already satisfied: requests in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (23.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.9.1)
# Requirement already satisfied: dataclasses-json in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.0.8)
# Requirement already satisfied: httpx in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.8.1)
# Requirement already satisfied: numpy in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.25.2)
# Requirement already satisfied: pandas in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.2.1)
# Requirement already satisfied: pillow>=9.0.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (10.2.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.5.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.16.0)
# Requirement already satisfied: pydantic<3,>2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from text-generation<0.8.0,>=0.7.0->llama-index-llms-huggingface) (2.7.1)
# Requirement already satisfied: sympy in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (1.12)
# Requirement already satisfied: jinja2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.4.2)
# Requirement already satisfied: accelerate>=0.21.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.27.0)
# Requirement already satisfied: psutil in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from accelerate>=0.21.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (5.9.8)
# Requirement already satisfied: attrs>=17.3.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.3.1)
# Requirement already satisfied: anyio in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.7.1)
# Requirement already satisfied: certifi in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.0.4)
# Requirement already satisfied: idna in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.6)
# Requirement already satisfied: sniffio in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.14.0)
# Requirement already satisfied: click in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (8.1.7)
# Requirement already satisfied: joblib in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.3.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pydantic<3,>2->text-generation<0.8.0,>=0.7.0->llama-index-llms-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pydantic<3,>2->text-generation<0.8.0,>=0.7.0->llama-index-llms-huggingface) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from requests->huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from requests->huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (1.26.18)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from jinja2->torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from sympy->torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (1.3.0)
# Requirement already satisfied: six>=1.5 in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages (1.0.1)

# %%
# Import transformer classes for generation

from transformers import AutoTokenizer, AutoModelForCausalLM, TextStreamer, BitsAndBytesConfig

# Import torch for datatype attributes

import torch

import os
from dotenv import load_dotenv

# %%
# Define model variable and load token from .env file

load_dotenv()

name = "meta-llama/Llama-2-70b-chat-hf"
token = env
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3 load_dotenv()
#       5 name = "meta-llama/Llama-2-70b-chat-hf"
# ----> 6 token = env
#
# NameError: name 'env' is not defined

# %%
# Instantiate tokenizer

tokenizer = AutoTokenizer.from_pretrained(
    name, 
    cache_dir='./model/', 
    use_auth_token=token)
# Out:
# /Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/transformers/models/auto/tokenization_auto.py:720: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(

# %%
# First define quantization settings (to reduce memory usage and computational requirements), then instantiate model

quantization_config = BitsAndBytesConfig(load_in_4bit=True)

model = AutoModelForCausalLM.from_pretrained(
    name, 
    cache_dir='./model/', 
    use_auth_token=token, 
    torch_dtype=torch.float16,
    quantization_config=quantization_config,
    rope_scaling={"type": "dynamic", "factor": 2})
# Out:
# Downloading shards:   0%|                                                                                                                                                                                              | 0/15 [28:16<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 quantization_config = BitsAndBytesConfig(load_in_4bit=True)
# ----> 3 model = AutoModelForCausalLM.from_pretrained(name,
#       4     cache_dir='./model/', use_auth_token=token, torch_dtype=torch.float16,
#       5     rope_scaling={"type": "dynamic", "factor": 2})
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:561, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     559 elif type(config) in cls._model_mapping.keys():
#     560     model_class = _get_model_class(config, cls._model_mapping)
# --> 561     return model_class.from_pretrained(
#     562         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     563     )
#     564 raise ValueError(
#     565     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     566     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     567 )
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/transformers/modeling_utils.py:3264, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3261 # We'll need to download and cache each checkpoint shard if the checkpoint is sharded.
#    3262 if is_sharded:
#    3263     # rsolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 3264     resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    3265         pretrained_model_name_or_path,
#    3266         resolved_archive_file,
#    3267         cache_dir=cache_dir,
#    3268         force_download=force_download,
#    3269         proxies=proxies,
#    3270         resume_download=resume_download,
#    3271         local_files_only=local_files_only,
#    3272         token=token,
#    3273         user_agent=user_agent,
#    3274         revision=revision,
#    3275         subfolder=subfolder,
#    3276         _commit_hash=commit_hash,
#    3277     )
#    3279 if (
#    3280     is_safetensors_available()
#    3281     and isinstance(resolved_archive_file, str)
#    3282     and resolved_archive_file.endswith(".safetensors")
#    3283 ):
#    3284     with safe_open(resolved_archive_file, framework="pt") as f:
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/transformers/utils/hub.py:1038, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1035 for shard_filename in tqdm(shard_filenames, desc="Downloading shards", disable=not show_progress_bar):
#    1036     try:
#    1037         # Load from URL
# -> 1038         cached_filename = cached_file(
#    1039             pretrained_model_name_or_path,
#    1040             shard_filename,
#    1041             cache_dir=cache_dir,
#    1042             force_download=force_download,
#    1043             proxies=proxies,
#    1044             resume_download=resume_download,
#    1045             local_files_only=local_files_only,
#    1046             token=token,
#    1047             user_agent=user_agent,
#    1048             revision=revision,
#    1049             subfolder=subfolder,
#    1050             _commit_hash=_commit_hash,
#    1051         )
#    1052     # We have already dealt with RepositoryNotFoundError and RevisionNotFoundError when getting the index, so
#    1053     # we don't have to catch them here.
#    1054     except EntryNotFoundError:
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/transformers/utils/hub.py:398, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     395 user_agent = http_user_agent(user_agent)
#     396 try:
#     397     # Load from URL or cache if already cached
# --> 398     resolved_file = hf_hub_download(
#     399         path_or_repo_id,
#     400         filename,
#     401         subfolder=None if len(subfolder) == 0 else subfolder,
#     402         repo_type=repo_type,
#     403         revision=revision,
#     404         cache_dir=cache_dir,
#     405         user_agent=user_agent,
#     406         force_download=force_download,
#     407         proxies=proxies,
#     408         resume_download=resume_download,
#     409         token=token,
#     410         local_files_only=local_files_only,
#     411     )
#     412 except GatedRepoError as e:
#     413     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/huggingface_hub/file_download.py:1492, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1489         if local_dir is not None:
#    1490             _check_disk_space(expected_size, local_dir)
# -> 1492     http_get(
#    1493         url_to_download,
#    1494         temp_file,
#    1495         proxies=proxies,
#    1496         resume_size=resume_size,
#    1497         headers=headers,
#    1498         expected_size=expected_size,
#    1499         displayed_filename=filename,
#    1500     )
#    1502 if local_dir is None:
#    1503     logger.debug(f"Storing {url} in cache at {blob_path}")
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/huggingface_hub/file_download.py:547, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries)
#     545 new_resume_size = resume_size
#     546 try:
# --> 547     for chunk in r.iter_content(chunk_size=DOWNLOAD_CHUNK_SIZE):
#     548         if chunk:  # filter out keep-alive new chunks
#     549             progress.update(len(chunk))
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Setup a prompt, pass it to the tokenizer and set up the text streamer

prompt = "### User:Who is the richest man in  \
          the world and what is his networth? \
          ### Assistant:"

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

streamer = TextStreamer(tokenizer, skip_prompt=True, skip_special_tokens=True)

# %%
# Run the model
output = model.generate(**inputs, 
                        streamer=streamer, 
                        use_cache=True, 
                        max_new_tokens=float('inf'))

# %%
# Convert the output tokens back to text 

output_text = tokenizer.decode(output[0], skip_special_tokens=True)

# %% [markdown]
# # RAG with LlamaIndex

# %%
# Import the prompt wrapper...but for llama index

from llama_index.core.prompts.prompts import SimpleInputPrompt



# Create a system prompt 
system_prompt = """[INST] <>
You are a helpful, respectful and honest assistant. Always answer as 
helpfully as possible, while being safe. Your answers should not include
any harmful, unethical, racist, sexist, toxic, dangerous, or illegal content.
Please ensure that your responses are socially unbiased and positive in nature.

If a question does not make any sense, or is not factually coherent, explain 
why instead of answering something not correct. If you don't know the answer 
to a question, please don't share false information.

Your goal is to provide answers relating to the financial performance of 
the company.<>
"""
# Throw together the query wrapper
query_wrapper_prompt = SimpleInputPrompt("{query_str} [/INST]")


# Complete the query prompt
query_wrapper_prompt.format(query_str='hello')
# Out:
# 'hello [/INST]'

# %%
# !pip list
# Out:
# Package                                 Version
# --------------------------------------- -------------
# accelerate                              0.27.0
# aiohttp                                 3.9.1
# aiosignal                               1.3.1
# annotated-types                         0.6.0
# anyio                                   3.7.1
# appnope                                 0.1.3
# asttokens                               2.0.5
# async-timeout                           4.0.3
# atlassian-python-api                    3.41.11
# attrs                                   23.2.0
# backcall                                0.2.0
# beautifulsoup4                          4.12.3
# bitsandbytes                            0.42.0
# Brotli                                  1.1.0
# certifi                                 2024.2.2
# charset-normalizer                      3.3.2
# click                                   8.1.7
# colorama                                0.4.6
# comm                                    0.1.2
# dataclasses-json                        0.5.14
# datasets                                2.18.0
# debugpy                                 1.6.7
# decorator                               5.1.1
# Deprecated                              1.2.14
# dill                                    0.3.8
# dirtyjson                               1.0.8
# distro                                  1.9.0
# einops                                  0.7.0
# entrypoints                             0.4
# exceptiongroup                          1.2.0
# executing                               0.8.3
# filelock                                3.13.1
# frozenlist                              1.4.1
# fsspec                                  2024.2.0
# greenlet                                3.0.3
# h11                                     0.14.0
# h2                                      4.1.0
# hpack                                   4.0.0
# html2text                               2024.2.26
# httpcore                                1.0.4
# httpx                                   0.27.0
# huggingface-hub                         0.20.3
# hyperframe                              6.0.1
# idna                                    3.6
# ipykernel                               6.29.3
# ipython                                 8.15.0
# jedi                                    0.18.1
# Jinja2                                  3.1.3
# jmespath                                1.0.1
# joblib                                  1.3.2
# jsonpatch                               1.33
# jsonpointer                             2.4
# jupyter-client                          7.1.2
# jupyter_core                            5.7.2
# langchain                               0.1.13
# langchain-community                     0.0.36
# langchain-core                          0.1.51
# langchain-text-splitters                0.0.1
# langsmith                               0.1.54
# llama-hub                               0.0.19
# llama-index                             0.7.21
# llama-index-agent-openai                0.2.3
# llama-index-cli                         0.1.12
# llama-index-core                        0.10.34
# llama-index-embeddings-huggingface      0.2.0
# llama-index-embeddings-openai           0.1.9
# llama-index-indices-managed-llama-cloud 0.1.6
# llama-index-legacy                      0.9.48
# llama-index-llms-huggingface            0.1.5
# llama-index-llms-openai                 0.1.16
# llama-index-multi-modal-llms-openai     0.1.5
# llama-index-program-openai              0.1.6
# llama-index-question-gen-openai         0.1.3
# llama-index-readers-file                0.1.20
# llama-index-readers-llama-parse         0.1.4
# llama-parse                             0.4.2
# llamaindex-py-client                    0.1.19
# MarkupSafe                              2.1.5
# marshmallow                             3.21.1
# matplotlib-inline                       0.1.6
# mpmath                                  1.3.0
# multidict                               6.0.5
# multiprocess                            0.70.16
# mypy-extensions                         1.0.0
# nest-asyncio                            1.6.0
# networkx                                3.2.1
# nltk                                    3.8.1
# numexpr                                 2.10.0
# numpy                                   1.26.4
# oauthlib                                3.2.2
# openai                                  1.25.2
# openapi-schema-pydantic                 1.2.4
# orjson                                  3.9.15
# packaging                               23.2
# pandas                                  2.2.1
# parso                                   0.8.3
# pexpect                                 4.8.0
# pickleshare                             0.7.5
# pillow                                  10.2.0
# pip                                     24.0
# platformdirs                            4.2.0
# prompt-toolkit                          3.0.36
# psutil                                  5.9.8
# ptyprocess                              0.7.0
# pure-eval                               0.2.2
# pyarrow                                 15.0.0
# pyarrow-hotfix                          0.6
# pydantic                                2.7.1
# pydantic_core                           2.18.2
# Pygments                                2.15.1
# pypdf                                   4.2.0
# PySocks                                 1.7.1
# python-dateutil                         2.9.0
# python-dotenv                           1.0.1
# pytz                                    2024.1
# PyYAML                                  6.0.1
# pyzmq                                   25.1.0
# regex                                   2023.12.25
# requests                                2.31.0
# requests-oauthlib                       2.0.0
# retrying                                1.3.4
# safetensors                             0.4.2
# scikit-learn                            1.4.1.post1
# scipy                                   1.12.0
# sentence-transformers                   2.7.0
# sentencepiece                           0.1.99
# setuptools                              69.1.1
# six                                     1.16.0
# sniffio                                 1.3.1
# soupsieve                               2.5
# SQLAlchemy                              2.0.30
# stack-data                              0.2.0
# striprtf                                0.0.26
# sympy                                   1.12
# tenacity                                8.2.3
# text-generation                         0.7.0
# threadpoolctl                           3.3.0
# tiktoken                                0.5.2
# tokenizers                              0.15.2
# torch                                   2.1.2.post102
# torchvision                             0.16.1
# tornado                                 6.3.3
# tqdm                                    4.66.2
# traitlets                               5.7.1
# transformers                            4.38.2
# tree_sitter                             0.20.4
# tree_sitter_languages                   1.9.1
# typing_extensions                       4.10.0
# typing-inspect                          0.9.0
# tzdata                                  2024.1
# urllib3                                 1.26.18
# wcwidth                                 0.2.5
# wheel                                   0.42.0
# wrapt                                   1.16.0
# xxhash                                  3.4.1
# yarl                                    1.9.4

# %%
# Import the llama index HF Wrapper
from llama_index.llms.huggingface import HuggingFaceLLM

# # Create a HF LLM using the llama index wrapper 
# llm = HuggingFaceLLM(context_window=4096,
#                     max_new_tokens=256,
#                     system_prompt=system_prompt,
#                     query_wrapper_prompt=query_wrapper_prompt,
#                     model=model,
#                     tokenizer=tokenizer)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[83], line 2
#       1 # Import the llama index HF Wrapper
# ----> 2 from llama_index.llms.huggingface import HuggingFaceLLM
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/llama_index/llms/__init__.py:15
#       3 from llama_index.llms.base import (
#       4     ChatMessage,
#       5     ChatResponse,
#    (...)
#      12     MessageRole,
#      13 )
#      14 from llama_index.llms.custom import CustomLLM
# ---> 15 from llama_index.llms.huggingface import HuggingFaceLLM
#      16 from llama_index.llms.langchain import LangChainLLM
#      17 from llama_index.llms.mock import MockLLM
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/llama_index/llms/huggingface/__init__.py:1
# ----> 1 from llama_index.llms.huggingface.base import (
#       2     HuggingFaceInferenceAPI,
#       3     HuggingFaceLLM,
#       4     TextGenerationInference,
#       5 )
#       7 __all__ = ["HuggingFaceLLM", "HuggingFaceInferenceAPI", "TextGenerationInference"]
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/llama_index/llms/huggingface/base.py:48
#      46 from llama_index.core.chat_engine.types import AgentChatResponse
#      47 from llama_index.core.tools.types import BaseTool
# ---> 48 from llama_index.llms.huggingface.utils import (
#      49     to_tgi_messages,
#      50     force_single_tool_call,
#      51     resolve_tgi_function_call,
#      52     get_max_input_length,
#      53     resolve_tool_choice,
#      54 )
#      55 from transformers import (
#      56     AutoModelForCausalLM,
#      57     AutoTokenizer,
#      58     StoppingCriteria,
#      59     StoppingCriteriaList,
#      60 )
#      61 from text_generation import (
#      62     Client as TGIClient,
#      63     AsyncClient as TGIAsyncClient,
#      64 )
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/llama_index/llms/huggingface/utils.py:8
#       3 from typing import Sequence, Union, List, Optional
#       4 from llama_index.core.base.llms.types import (
#       5     ChatMessage,
#       6     ChatResponse,
#       7 )
# ----> 8 from text_generation.types import (
#       9     Message,
#      10 )
#      13 def resolve_tgi_function_call(url: str) -> bool:
#      14     url = f"{url}/info"
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/text_generation/__init__.py:17
#       1 # Copyright 2023 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "0.6.0"
# ---> 17 from text_generation.client import Client, AsyncClient
#      18 from text_generation.inference_api import InferenceAPIClient, InferenceAPIAsyncClient
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/text_generation/client.py:8
#       5 from pydantic import ValidationError
#       6 from typing import Dict, Optional, List, AsyncIterator, Iterator, Union
# ----> 8 from text_generation.types import (
#       9     StreamResponse,
#      10     Response,
#      11     Request,
#      12     Parameters,
#      13     Grammar,
#      14     ChatRequest,
#      15     ChatCompletionChunk,
#      16     ChatComplete,
#      17     Message,
#      18     Tool,
#      19 )
#      20 from text_generation.errors import parse_error
#      23 class Client:
#
# File ~/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/text_generation/types.py:2
#       1 from enum import Enum
# ----> 2 from pydantic import BaseModel, field_validator
#       3 from typing import Optional, List, Union, Any
#       5 from text_generation.errors import ValidationError
#
# ImportError: cannot import name 'field_validator' from 'pydantic' (/Users/steven/opt/anaconda3/envs/llama_banker/lib/python3.12/site-packages/pydantic/__init__.py)

# %%
# Import embeddings wrapper
from llama_index.embeddings import LangchainEmbedding

# Import HF embeddings - need these to represent document chunks
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
     

# # Create and dl embeddings instance  
# embeddings=LangchainEmbedding(
#     HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# )
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[80], line 2
#       1 # Import embeddings wrapper
# ----> 2 from llama_index.embeddings import LangchainEmbedding
#       4 # Import HF embeddings - need these to represent document chunks
#       5 from langchain.embeddings.huggingface import HuggingFaceEmbeddings
#
# ImportError: cannot import name 'LangchainEmbedding' from 'llama_index.embeddings' (unknown location)

# %%
# Import dependencies to change service context. This is needed because by default, LlamaIndex works with OpenAI

from llama_index import set_global_service_context
from llama_index import ServiceContext
     

# # Create new service context instance
# service_context = ServiceContext.from_defaults(
#     chunk_size=1024,
#     llm=llm,
#     embed_model=embeddings
# )

# # Set the service context
# set_global_service_context(service_context)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[69], line 3
#       1 # Import dependencies to change service context. This is needed because by default, LlamaIndex works with OpenAI
# ----> 3 from llama_index import set_global_service_context
#       4 from llama_index import ServiceContext
#
# ImportError: cannot import name 'set_global_service_context' from 'llama_index' (unknown location)

# %%
# Import dependencies to load documents 

from llama_index import VectorStoreIndex, download_loader
from pathlib import Path
     

# Download PDF Loader 
PyMuPDFReader = download_loader("PyMuPDFReader")
# Create PDF Loader
loader = PyMuPDFReader()
# Load documents 
documents = loader.load(file_path=Path('./data/annualreport.pdf'), metadata=True)
     

# Create an index - we'll be able to query this in a sec
index = VectorStoreIndex.from_documents(documents)

# %%
# Setup index query engine using LLM 
query_engine = index.as_query_engine()
     

# Test out a query in natural
response = query_engine.query("what was the FY2022 return on equity?")
